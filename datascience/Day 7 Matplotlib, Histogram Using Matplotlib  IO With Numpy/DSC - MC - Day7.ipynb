# %%
from matplotlib import pyplot as plt
import numpy as np
import math
x = np.arange(0,math.pi*2,0.05)
y = np.sin(x)
plt.plot(x,y)
plt.xlabel('angle')
plt.ylabel('sin')
plt.show()

# %%
from numpy import *
from pylab import *
x = linspace(-3,3,30)
y = x**2
plot(x,y)
show()

# %%
from pylab import *
from numpy import *
x = linspace(-3,3,30)
y = x**2
plot(x,y,'b.')
show()

# %%
from pylab import *
x = linspace(-3,3,30)
plot(x,sin(x))
plot(x,cos(x),'r.')
show()
